# %%
import pandas as pd 
import folium
import numpy as np
from folium import Choropleth, Circle, Marker
from folium.plugins import HeatMap, MarkerCluster

# %%
calls = pd.read_csv('./data_files/911.csv')
calls
# Out:
#               lat        lng  \
# 0       40.297876 -75.581294
# 1       40.258061 -75.264680
# 2       40.121182 -75.351975
# 3       40.116153 -75.343513
# 4       40.251492 -75.603350
# ...           ...        ...
# 663517  40.157956 -75.348060
# 663518  40.136306 -75.428697
# 663519  40.013779 -75.300835
# 663520  40.121603 -75.351437
# 663521  40.015046 -75.299674
#
#                                                      desc      zip  \
# 0       REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1       BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2       HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3       AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4       CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                   ...      ...
# 663517  SUNSET AVE & WOODLAND AVE; EAST NORRITON; 2020...  19403.0
# ...

# %%
call_unit = calls['title'].str.split(':', expand=True)
calls['call_unit'] = call_unit[0]

# %%
calls = calls[:1500]
calls['call_unit'].unique()
# Out:
# array(['EMS', 'Fire', 'Traffic'], dtype=object)

# %%
m = folium.Map(location=[np.mean(calls['lat']),np.mean(calls['lng'])], zoom_start=10)
car = folium.FeatureGroup(name='Traffic Incident', col='green')
ems = folium.FeatureGroup(name='EMS', col='blue')
fire = folium.FeatureGroup(name='Fire', col='red')

for index, info in calls.iterrows():
    if info['call_unit'] == 'Traffic':
        car_marker = folium.Marker([info['lat'], info['lng']], tooltip = f"{info['title']}, {info['timeStamp']}",icon=folium.Icon(prefix='fa',icon='car', color='green'))
        car.add_child(car_marker)
        m.add_child(car)



    if info['call_unit'] == 'EMS':
        ems_marker = folium.Marker([info['lat'], info['lng']], tooltip = f"{info['title']}, {info['timeStamp']}",icon=folium.Icon(prefix='fa',icon='ambulance'))
        ems.add_child(ems_marker)
        m.add_child(ems)



    if info['call_unit'] == 'Fire':
        fire_marker = folium.Marker([info['lat'], info['lng']], tooltip = f"{info['title']}, {info['timeStamp']}",icon=folium.Icon(prefix='fa',icon='fire-extinguisher', color='red'))
        fire.add_child(fire_marker)
        m.add_child(fire)
    
folium.map.LayerControl('topleft', collapsed= False).add_to(m) 


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
